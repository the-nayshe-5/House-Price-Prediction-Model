# %% [markdown]
# # House Pricing Data Explorartory Data Analysis

# %% [markdown]
# #### Importing Packages and Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Surpress warnings:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %% [markdown]
# #### Glimpsing at the data

# %%
df_train = pd.read_csv('train_clean.csv')
df_test = pd.read_csv('test_clean.csv')

# %%
df_train.set_index('Id', inplace = True)

# %%
df_test.set_index('Id', inplace = True)

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour  \
# 0   1          60       RL         65.0     8450      Reg         Lvl
# 1   2          20       RL         80.0     9600      Reg         Lvl
# 2   3          60       RL         68.0    11250      IR1         Lvl
# 3   4          70       RL         60.0     9550      IR1         Lvl
# 4   5          60       RL         84.0    14260      IR1         Lvl
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# ...

# %%
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour  \
# 0  1461          20       RH         80.0    11622      Reg         Lvl
# 1  1462          20       RL         81.0    14267      IR1         Lvl
# 2  1463          60       RL         74.0    13830      IR1         Lvl
# 3  1464          60       RL         78.0     9978      IR1         Lvl
# 4  1465         120       RL         43.0     5005      IR1         HLS
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl        NAmes      Feedr       Norm     1Fam     1Story
# 1    Corner       Gtl        NAmes       Norm       Norm     1Fam     1Story
# 2    Inside       Gtl      Gilbert       Norm       Norm     1Fam     2Story
# 3    Inside       Gtl      Gilbert       Norm       Norm     1Fam     2Story
# 4    Inside       Gtl      StoneBr       Norm       Norm   TwnhsE     1Story
#
# ...

# %%
df_train.shape
# Out:
# (1458, 74)

# %%
df_test.shape
# Out:
# (1459, 73)

# %%
df_train.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'LotShape',
#        'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
fig.suptitle('Train data correlations with Sale Price')

# Lot Frontage
sns.scatterplot(ax=axes[0], data = df_train, x = 'LotFrontage', y = 'SalePrice')
axes[0].set_title('Lot Frontage vs Sale Price')

# Lot Area
sns.scatterplot(ax=axes[1], data = df_train, x = 'LotArea', y = 'SalePrice')
axes[1].set_title('Lot Area vs Sale Price')

plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
fig.suptitle('Train data correlations with Sale Price')

# MS Sub Class
sns.barplot(ax=axes[0], data = df_train, x = 'MSSubClass', y = 'SalePrice', hue = 'MSSubClass')
axes[0].set_title('MS Sub-Class vs Sale Price')

# MS Zoning
sns.barplot(ax=axes[1], data = df_train, x = 'MSZoning', y = 'SalePrice', hue = 'MSZoning')
axes[1].set_title('MS Zoning vs Sale Price')

plt.show()

# %% [markdown]
#  - *2-STORY 1946 & NEWER are the highest priced Houses Sub Class.*
#  - *For zones, Floating Village Residential are the highest priced, whereas, Commercial zones are the lowest priced.*

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
fig.suptitle('Train data correlations with Sale Price')

# Land Contour
sns.barplot(ax=axes[0], data = df_train, x = 'LandContour', y = 'SalePrice', hue = 'LandContour')
axes[0].set_title('Land Contour vs Sale Price')

# Lot Shape
sns.barplot(ax=axes[1], data = df_train, x = 'LotShape', y = 'SalePrice', hue = 'LotShape')
axes[1].set_title('Lot Shape vs Sale Price')

plt.show()

# %%
# Sale Condition
sns.barplot(data = df_train, x = 'SaleCondition', y = 'SalePrice', hue = 'SaleCondition')
plt.title('Sale Condition vs Sale Price')
plt.show()

# %%
# Neighborhood
plt.figure(figsize = (15,5))
sns.barplot(data = df_train, x = 'Neighborhood', y = 'SalePrice', hue = 'Neighborhood')
plt.show()

# %%
# Year Built
plt.figure(figsize = (15,5))
sns.barplot(data = df_train, x = 'YearBuilt', y = 'SalePrice', hue = 'YearBuilt')
plt.show()

# %%
plt.figure(figsize = (20,20))
sns.heatmap(df_train.corr(), annot = True, cmap = 'RdBu')
plt.show()

# %% [markdown]
# ### Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
categorical = ['MSZoning', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 
               'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
               'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 
               'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
               'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
               'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 
               'PavedDrive', 'WoodDeckSF', 'SaleType', 'SaleCondition']

# %%
for i in categorical:
    encoder = LabelEncoder()
    df_train[i]= encoder.fit_transform(df_train[i].values)

# %%
for i in categorical:
    encoder = LabelEncoder()
    df_test[i]= encoder.fit_transform(df_test[i].values)

# %%
df_train.head()
# Out:
#     MSSubClass  MSZoning  LotFrontage  LotArea  LotShape  LandContour  \
# Id
# 1           60         3         65.0     8450         3            3
# 2           20         3         80.0     9600         3            3
# 3           60         3         68.0    11250         0            3
# 4           70         3         60.0     9550         0            3
# 5           60         3         84.0    14260         0            3
#
#     LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# Id
# 1           4          0             5           2           2         0
# 2           2          0            24           1           2         0
# 3           4          0             5           2           2         0
# 4           0          0             6           2           2         0
# 5           2          0            15           2           2         0
#
#     HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  RoofStyle  \
# Id
# ...

# %%
df_test.head()
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  LotShape  LandContour  \
# Id
# 1461          20         3         80.0    11622         3            3
# 1462          20         4         81.0    14267         0            3
# 1463          60         4         74.0    13830         0            3
# 1464          60         4         78.0     9978         0            3
# 1465         120         4         43.0     5005         0            1
#
#       LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# Id
# 1461          4          0            12           1           2         0
# 1462          0          0            12           2           2         0
# 1463          4          0             8           2           2         0
# 1464          4          0             8           2           2         0
# 1465          4          0            22           2           2         4
#
#       HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# ...

# %%
df_train.to_csv('train_data.csv', index = False)
df_test.to_csv('test_data.csv', index = True)
